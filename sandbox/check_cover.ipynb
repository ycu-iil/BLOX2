# %%
import pandas as pd

# all_path = "../data/zinc_dft/properties.csv"
all_path = "../data/material/properties.csv"

df = pd.read_csv(all_path)
df
# Out:
#       Band gap  Permittivity
# 0         3.05           3.3
# 1         1.99           5.4
# 2         6.35           2.9
# 3         4.30           4.5
# 4         0.81           7.1
# ...        ...           ...
# 1272      2.50           4.3
# 1273      2.77           5.0
# 1274      3.46           4.5
# 1275      2.30           5.3
# 1276      4.72           2.8
#
# [1277 rows x 2 columns]

# %%
X = df.to_numpy()
X
# Out:
# array([[3.05, 3.3 ],
#        [1.99, 5.4 ],
#        [6.35, 2.9 ],
#        ...,
#        [3.46, 4.5 ],
#        [2.3 , 5.3 ],
#        [4.72, 2.8 ]], shape=(1277, 2))

# %%
from blox2 import plot_buffer_union

plot_buffer_union(X, radius=1, k=100)
# Out:
# (<Axes: title={'center': 'Union of buffers (ε=1)'}>,
#  <MULTIPOLYGON (((1.013 2.493, 0.796 2.817, 0.75 3.048, 0.683 3.093, 0.619 3....>)
